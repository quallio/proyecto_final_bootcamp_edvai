# %%
# LEEMOS EL DATASET QUE ESTÁ EN FORMATO JSON Y LO CONVERTIMOS EN UN DATAFRAME

import pandas as pd

customer_file = 'data/customers.json'
df_json_nested = pd.read_json(customer_file, lines= True)

df_json_nested.head(3)
# Out:
#    fraudulent                                           customer  \
# 0       False  {'customerEmail': 'josephhoward@yahoo.com', 'c...
# 1        True  {'customerEmail': 'evansjeffery@yahoo.com', 'c...
# 2       False  {'customerEmail': 'andersonwilliam@yahoo.com',...
#
#                                               orders  \
# 0  [{'orderId': 'vjbdvd', 'orderAmount': 18, 'ord...
# 1  [{'orderId': 'nlghpa', 'orderAmount': 45, 'ord...
# 2  [{'orderId': 'yk34y2', 'orderAmount': 33, 'ord...
#
#                                       paymentMethods  \
# 0  [{'paymentMethodId': 'wt07xm68b', 'paymentMeth...
# 1  [{'paymentMethodId': 'y3xp697jx', 'paymentMeth...
# 2  [{'paymentMethodId': '8pneoi03z', 'paymentMeth...
#
#                                         transactions
# 0  [{'transactionId': 'a9lcj51r', 'orderId': 'vjb...
# 1  [{'transactionId': '5mi94sfw', 'orderId': 'nlg...
# 2  [{'transactionId': 'q3lyvbza', 'orderId': 'yk3...

# %%
# Customer Dataframe
# el valor dentro de cada celda en `Customer` es un json.

from pandas import json_normalize

customers_df = json_normalize(df_json_nested['customer'])
customers_df.head(3)
# Out:
#                customerEmail   customerPhone        customerDevice  \
# 0     josephhoward@yahoo.com    400-108-5415  yyeiaxpltf82440jnb3v
# 1     evansjeffery@yahoo.com  1-788-091-7546  r0jpm7xaeqqa3kr6mzum
# 2  andersonwilliam@yahoo.com    024.420.0375  4m7h5ipl1shyavt6vv2r
#
#                          customerIPAddress  \
# 0                             8.129.104.40
# 1                          219.173.211.202
# 2  67b7:3db8:67e0:3bea:b9d0:90c1:2b60:b9f0
#
#                               customerBillingAddress
# 0            5493 Jones Islands\nBrownside, CA 51896
# 1  356 Elizabeth Inlet Suite 120\nPort Joshuabury...
# 2     8478 Sean Ridges Apt. 441\nDavisberg, PR 72250

# %%
# Orders Dataframe
# el valor dentro de cada celda en `orders` es una lista.

orders_nested = pd.DataFrame([md for md in df_json_nested["orders"]])

orders_list=[]
for index,row in orders_nested.iterrows():
    for order in row:
        if order != None:
            orders_list.append(order)           
orders_df = pd.DataFrame(orders_list)

orders_df.head(3)
# Out:
#   orderId  orderAmount orderState  \
# 0  vjbdvd           18    pending
# 1  yp6x27           26  fulfilled
# 2  nlghpa           45  fulfilled
#
#                             orderShippingAddress
# 0        5493 Jones Islands\nBrownside, CA 51896
# 1        5493 Jones Islands\nBrownside, CA 51896
# 2  898 Henry Ports\nNew Keithview, CA 95893-2497

# %%
# Transactions Dataframe
# el valor dentro de cada celda en `transactions` es una lista

transactions_nested = pd.DataFrame([md for md in df_json_nested["transactions"]])

transactions_list=[]
for index,row in transactions_nested.iterrows():
    for transaction in row:
        if transaction != None:
            transactions_list.append(transaction)           
transactions_df = pd.DataFrame(transactions_list)

transactions_df.head(3)
# Out:
#   transactionId orderId paymentMethodId  transactionAmount  transactionFailed
# 0      a9lcj51r  vjbdvd       wt07xm68b                 18              False
# 1      y4wcv03i  yp6x27       wt07xm68b                 26              False
# 2      5mi94sfw  nlghpa       41ug157xz                 45              False

# %%
# Payment Dataframe
# el valor dentro de cada celda en `payment_methods` es una lista

payment_nested = pd.DataFrame([md for md in df_json_nested["paymentMethods"]])

payment_methods_list=[]
for index,row in payment_nested.iterrows():
    for order in row:
        if order != None:
            payment_methods_list.append(order)           
payment_methods_df = pd.DataFrame(payment_methods_list)

payment_methods_df.head(3)
# Out:
#   paymentMethodId  paymentMethodRegistrationFailure paymentMethodType  \
# 0       wt07xm68b                              True              card
# 1       y3xp697jx                              True           bitcoin
# 2       6krszxc05                             False              card
#
#   paymentMethodProvider   paymentMethodIssuer
# 0          JCB 16 digit  Citizens First Banks
# 1         VISA 16 digit          Solace Banks
# 2         VISA 16 digit        Vertex Bancorp

# %%
# Fraudulent Dataframe

fraudulent_df = df_json_nested['fraudulent']

fraudulent_df.head(3)
# Out:
# 0    False
# 1     True
# 2    False
# Name: fraudulent, dtype: bool

# %%
# Unir / Mergear dataframes

data = pd.concat([customers_df, orders_df, payment_methods_df, transactions_df, fraudulent_df], axis=1)

data.head(3)
# Out:
#                customerEmail   customerPhone        customerDevice  \
# 0     josephhoward@yahoo.com    400-108-5415  yyeiaxpltf82440jnb3v
# 1     evansjeffery@yahoo.com  1-788-091-7546  r0jpm7xaeqqa3kr6mzum
# 2  andersonwilliam@yahoo.com    024.420.0375  4m7h5ipl1shyavt6vv2r
#
#                          customerIPAddress  \
# 0                             8.129.104.40
# 1                          219.173.211.202
# 2  67b7:3db8:67e0:3bea:b9d0:90c1:2b60:b9f0
#
#                               customerBillingAddress orderId  orderAmount  \
# 0            5493 Jones Islands\nBrownside, CA 51896  vjbdvd         18.0
# 1  356 Elizabeth Inlet Suite 120\nPort Joshuabury...  yp6x27         26.0
# 2     8478 Sean Ridges Apt. 441\nDavisberg, PR 72250  nlghpa         45.0
#
#   orderState                           orderShippingAddress paymentMethodId  \
# 0    pending        5493 Jones Islands\nBrownside, CA 51896       wt07xm68b
# 1  fulfilled        5493 Jones Islands\nBrownside, CA 51896       y3xp697jx
# 2  fulfilled  898 Henry Ports\nNew Keithview, CA 95893-2497       6krszxc05
#
#   paymentMethodRegistrationFailure paymentMethodType paymentMethodProvider  \
# 0                             True              card          JCB 16 digit
# 1                             True           bitcoin         VISA 16 digit
# 2                            False              card         VISA 16 digit
#
#     paymentMethodIssuer transactionId orderId paymentMethodId  \
# 0  Citizens First Banks      a9lcj51r  vjbdvd       wt07xm68b
# 1          Solace Banks      y4wcv03i  yp6x27       wt07xm68b
# 2        Vertex Bancorp      5mi94sfw  nlghpa       41ug157xz
#
#    transactionAmount  transactionFailed fraudulent
# 0                 18              False      False
# 1                 26              False       True
# 2                 45              False      False

# %%
# Transformación de columnas

# Vamos a transformar los valores de algunas columnas que parecen únicos para que sean utilizables.

from funpymodeling.exploratory import status 

status(data)
# Out:
#                             variable  q_nan     p_nan  q_zeros   p_zeros  \
# 0                      customerEmail    455  0.730337        0  0.000000
# 1                      customerPhone    455  0.730337        0  0.000000
# 2                     customerDevice    455  0.730337        0  0.000000
# 3                  customerIPAddress    455  0.730337        0  0.000000
# 4             customerBillingAddress    455  0.730337        0  0.000000
# 5                            orderId    145  0.232745        0  0.000000
# 6                        orderAmount    145  0.232745        0  0.000000
# 7                         orderState    145  0.232745        0  0.000000
# 8               orderShippingAddress    145  0.232745        0  0.000000
# 9                    paymentMethodId    281  0.451043        0  0.000000
# 10  paymentMethodRegistrationFailure    281  0.451043      302  0.484751
# 11                 paymentMethodType    281  0.451043        0  0.000000
# 12             paymentMethodProvider    281  0.451043        0  0.000000
# 13               paymentMethodIssuer    281  0.451043        0  0.000000
# 14                     transactionId      0  0.000000        0  0.000000
# 15                           orderId      0  0.000000        0  0.000000
# 16                   paymentMethodId      0  0.000000        0  0.000000
# 17                 transactionAmount      0  0.000000        0  0.000000
# 18                 transactionFailed      0  0.000000      455  0.730337
# 19                        fraudulent    455  0.730337      107  0.171750
#
#     unique     type
# 0      161   object
# 1      168   object
# 2      168   object
# 3      165   object
# 4      166   object
# 5      478   object
# 6       67  float64
# 7        3   object
# 8      274   object
# 9      342   object
# 10       2   object
# 11       4   object
# 12      10   object
# 13      20   object
# 14     623   object
# 15     478   object
# 16     237   object
# 17      67    int64
# 18       2     bool
# 19       2   object

# %%
# Podemos observar que hay columnas repetidas como ser `orderId` y `paymentMethodId`.
# Procedemos a eliminar los duplicados

data = data.loc[:,~data.columns.duplicated()].copy()

status(data)
# Out:
#                             variable  q_nan     p_nan  q_zeros   p_zeros  \
# 0                      customerEmail    455  0.730337        0  0.000000
# 1                      customerPhone    455  0.730337        0  0.000000
# 2                     customerDevice    455  0.730337        0  0.000000
# 3                  customerIPAddress    455  0.730337        0  0.000000
# 4             customerBillingAddress    455  0.730337        0  0.000000
# 5                            orderId    145  0.232745        0  0.000000
# 6                        orderAmount    145  0.232745        0  0.000000
# 7                         orderState    145  0.232745        0  0.000000
# 8               orderShippingAddress    145  0.232745        0  0.000000
# 9                    paymentMethodId    281  0.451043        0  0.000000
# 10  paymentMethodRegistrationFailure    281  0.451043      302  0.484751
# 11                 paymentMethodType    281  0.451043        0  0.000000
# 12             paymentMethodProvider    281  0.451043        0  0.000000
# 13               paymentMethodIssuer    281  0.451043        0  0.000000
# 14                     transactionId      0  0.000000        0  0.000000
# 15                 transactionAmount      0  0.000000        0  0.000000
# 16                 transactionFailed      0  0.000000      455  0.730337
# 17                        fraudulent    455  0.730337      107  0.171750
#
#     unique     type
# 0      161   object
# 1      168   object
# 2      168   object
# 3      165   object
# 4      166   object
# 5      478   object
# 6       67  float64
# 7        3   object
# 8      274   object
# 9      342   object
# 10       2   object
# 11       4   object
# 12      10   object
# 13      20   object
# 14     623   object
# 15      67    int64
# 16       2     bool
# 17       2   object

# %%
# custmerEmail

# Generalmente solemos recibir mail de clientes que utilizan servicios de mensajería como `@hotmail`, `@yahoo` y `@gmail`. Esos son los tipos de mail más comunes.

# Vamos a clasificar los mails como `hotmail`, `yahoo`, `gmail` y `weird`. 
# 'weird' son aquellos raros que no responden a los proveedores más conocidos

# Aclaración: Esto se puede hacer usando expresiones regulares (Regex) y funciones lambda también, pero es más práctico de seguir / entender lo que hace el programa de la siguiente manera:

email_domains= []
mails= []
popular_providers = ['yahoo', 'gmail', 'hotmail']

for email in data['customerEmail']:
    try:
        """
        Si email = "edvai@yahoo.com"

        aux = yahoo.com
        mail = yahoo
        domain = com
        """
        aux = email.split('@')[1]
        domain = aux.split('.')[1]
        mail = aux.split('.')[0]
        
        if mail in popular_providers:
            mails.append(mail)
        else:
            mails.append('other')
        email_domains.append(domain)
        
    except:
        email_domains.append('weird')
        mails.append('weird')
        # print(email)

# Las listas creadas las convertimos a columnas del dataframe:

data['emailDomain'] = email_domains
data['emailProvider'] = mails

data.head(3)
# Out:
#                customerEmail   customerPhone        customerDevice  \
# 0     josephhoward@yahoo.com    400-108-5415  yyeiaxpltf82440jnb3v
# 1     evansjeffery@yahoo.com  1-788-091-7546  r0jpm7xaeqqa3kr6mzum
# 2  andersonwilliam@yahoo.com    024.420.0375  4m7h5ipl1shyavt6vv2r
#
#                          customerIPAddress  \
# 0                             8.129.104.40
# 1                          219.173.211.202
# 2  67b7:3db8:67e0:3bea:b9d0:90c1:2b60:b9f0
#
#                               customerBillingAddress orderId  orderAmount  \
# 0            5493 Jones Islands\nBrownside, CA 51896  vjbdvd         18.0
# 1  356 Elizabeth Inlet Suite 120\nPort Joshuabury...  yp6x27         26.0
# 2     8478 Sean Ridges Apt. 441\nDavisberg, PR 72250  nlghpa         45.0
#
#   orderState                           orderShippingAddress paymentMethodId  \
# 0    pending        5493 Jones Islands\nBrownside, CA 51896       wt07xm68b
# 1  fulfilled        5493 Jones Islands\nBrownside, CA 51896       y3xp697jx
# 2  fulfilled  898 Henry Ports\nNew Keithview, CA 95893-2497       6krszxc05
#
#   paymentMethodRegistrationFailure paymentMethodType paymentMethodProvider  \
# 0                             True              card          JCB 16 digit
# 1                             True           bitcoin         VISA 16 digit
# 2                            False              card         VISA 16 digit
#
#     paymentMethodIssuer transactionId  transactionAmount  transactionFailed  \
# 0  Citizens First Banks      a9lcj51r                 18              False
# 1          Solace Banks      y4wcv03i                 26              False
# 2        Vertex Bancorp      5mi94sfw                 45              False
#
#   fraudulent emailDomain emailProvider
# 0      False         com         yahoo
# 1       True         com         yahoo
# 2      False         com         yahoo

# %%
# Eliminamos la columna `customerEmail`:

data = data.drop(['customerEmail'], axis=1)

data.head(3)
# Out:
#     customerPhone        customerDevice  \
# 0    400-108-5415  yyeiaxpltf82440jnb3v
# 1  1-788-091-7546  r0jpm7xaeqqa3kr6mzum
# 2    024.420.0375  4m7h5ipl1shyavt6vv2r
#
#                          customerIPAddress  \
# 0                             8.129.104.40
# 1                          219.173.211.202
# 2  67b7:3db8:67e0:3bea:b9d0:90c1:2b60:b9f0
#
#                               customerBillingAddress orderId  orderAmount  \
# 0            5493 Jones Islands\nBrownside, CA 51896  vjbdvd         18.0
# 1  356 Elizabeth Inlet Suite 120\nPort Joshuabury...  yp6x27         26.0
# 2     8478 Sean Ridges Apt. 441\nDavisberg, PR 72250  nlghpa         45.0
#
#   orderState                           orderShippingAddress paymentMethodId  \
# 0    pending        5493 Jones Islands\nBrownside, CA 51896       wt07xm68b
# 1  fulfilled        5493 Jones Islands\nBrownside, CA 51896       y3xp697jx
# 2  fulfilled  898 Henry Ports\nNew Keithview, CA 95893-2497       6krszxc05
#
#   paymentMethodRegistrationFailure paymentMethodType paymentMethodProvider  \
# 0                             True              card          JCB 16 digit
# 1                             True           bitcoin         VISA 16 digit
# 2                            False              card         VISA 16 digit
#
#     paymentMethodIssuer transactionId  transactionAmount  transactionFailed  \
# 0  Citizens First Banks      a9lcj51r                 18              False
# 1          Solace Banks      y4wcv03i                 26              False
# 2        Vertex Bancorp      5mi94sfw                 45              False
#
#   fraudulent emailDomain emailProvider
# 0      False         com         yahoo
# 1       True         com         yahoo
# 2      False         com         yahoo

# %%
# customerIPAddress

# Por ejemplo, nuestro localhost es 127.0.0.1
# Según el protocolo, podemos llegar a tener una subnet mask 255.255.255.255 (la máxima cantidad de caracteres numéricos), es decir podes alcanzar una longitud de:

longitudIP = 255*255*255*255
print(longitudIP)
# Out:
# 4228250625

# %%
# Pero hay IPs más extensas (>15) que contienen letras por ejemplo: `67b7:3db8:67e0:3bea:b9d0:90c1:2b60:b9f0`

# Entonces lo que vamos a hacer es crear 2 columnas nuevas dependiendo el tipo de IP: `customerIPAddress` y `digits_and_letters`.

# Aclaración: Esto se puede hacer usando expresiones regulares para buscar letras en vez de medir longitud y funciones lambda, pero es más práctico de seguir / entender lo que hace el programa de la siguiente manera:

# %%
IP_addresses = []
for address in data['customerIPAddress']:

    # A veces lo toma como flotante al address
    aux_address = str(address)
    
    if len(aux_address) > 15:
        IP_addresses.append('digits_and_letters')
    else:
        IP_addresses.append('only_numbers')

data['customerIPAddressSimplified'] = IP_addresses

data.head(3)
# Out:
#     customerPhone        customerDevice  \
# 0    400-108-5415  yyeiaxpltf82440jnb3v
# 1  1-788-091-7546  r0jpm7xaeqqa3kr6mzum
# 2    024.420.0375  4m7h5ipl1shyavt6vv2r
#
#                          customerIPAddress  \
# 0                             8.129.104.40
# 1                          219.173.211.202
# 2  67b7:3db8:67e0:3bea:b9d0:90c1:2b60:b9f0
#
#                               customerBillingAddress orderId  orderAmount  \
# 0            5493 Jones Islands\nBrownside, CA 51896  vjbdvd         18.0
# 1  356 Elizabeth Inlet Suite 120\nPort Joshuabury...  yp6x27         26.0
# 2     8478 Sean Ridges Apt. 441\nDavisberg, PR 72250  nlghpa         45.0
#
#   orderState                           orderShippingAddress paymentMethodId  \
# 0    pending        5493 Jones Islands\nBrownside, CA 51896       wt07xm68b
# 1  fulfilled        5493 Jones Islands\nBrownside, CA 51896       y3xp697jx
# 2  fulfilled  898 Henry Ports\nNew Keithview, CA 95893-2497       6krszxc05
#
#   paymentMethodRegistrationFailure paymentMethodType paymentMethodProvider  \
# 0                             True              card          JCB 16 digit
# 1                             True           bitcoin         VISA 16 digit
# 2                            False              card         VISA 16 digit
#
#     paymentMethodIssuer transactionId  transactionAmount  transactionFailed  \
# 0  Citizens First Banks      a9lcj51r                 18              False
# 1          Solace Banks      y4wcv03i                 26              False
# 2        Vertex Bancorp      5mi94sfw                 45              False
#
#   fraudulent emailDomain emailProvider customerIPAddressSimplified
# 0      False         com         yahoo                only_numbers
# 1       True         com         yahoo                only_numbers
# 2      False         com         yahoo          digits_and_letters

# %%
# Eliminamos la columna `customerIPAddress`

data = data.drop(['customerIPAddress'], axis=1)

data.head(3)
# Out:
#     customerPhone        customerDevice  \
# 0    400-108-5415  yyeiaxpltf82440jnb3v
# 1  1-788-091-7546  r0jpm7xaeqqa3kr6mzum
# 2    024.420.0375  4m7h5ipl1shyavt6vv2r
#
#                               customerBillingAddress orderId  orderAmount  \
# 0            5493 Jones Islands\nBrownside, CA 51896  vjbdvd         18.0
# 1  356 Elizabeth Inlet Suite 120\nPort Joshuabury...  yp6x27         26.0
# 2     8478 Sean Ridges Apt. 441\nDavisberg, PR 72250  nlghpa         45.0
#
#   orderState                           orderShippingAddress paymentMethodId  \
# 0    pending        5493 Jones Islands\nBrownside, CA 51896       wt07xm68b
# 1  fulfilled        5493 Jones Islands\nBrownside, CA 51896       y3xp697jx
# 2  fulfilled  898 Henry Ports\nNew Keithview, CA 95893-2497       6krszxc05
#
#   paymentMethodRegistrationFailure paymentMethodType paymentMethodProvider  \
# 0                             True              card          JCB 16 digit
# 1                             True           bitcoin         VISA 16 digit
# 2                            False              card         VISA 16 digit
#
#     paymentMethodIssuer transactionId  transactionAmount  transactionFailed  \
# 0  Citizens First Banks      a9lcj51r                 18              False
# 1          Solace Banks      y4wcv03i                 26              False
# 2        Vertex Bancorp      5mi94sfw                 45              False
#
#   fraudulent emailDomain emailProvider customerIPAddressSimplified
# 0      False         com         yahoo                only_numbers
# 1       True         com         yahoo                only_numbers
# 2      False         com         yahoo          digits_and_letters

# %%
# customerBillingAddress vrs. orderShippingAddress

# Tomar el nombre de la ciudad, de toda la dirección que tenemos.

def extract_city_name(name_column):
    city_list = []

    for address in data[name_column]:
        try:
            """
            Si address = "5493 Jones Islands\nBrownside, CA 51896"

            aux = "Brownside, CA 51896"
            city_with_number = "CA 51896"
            city = "CA"
            """
            aux = address.split('\n')[1]
            city_with_number = aux.split(', ')[1]
            city = city_with_number.split(' ')[0]
            
            city_list.append(city)
                
        except:
            # Sino aparece el nombre de la ciudad asignamos: unknown
            city_list.append("unknown")
    
    return city_list

data["customerBillingAddress"] = extract_city_name("customerBillingAddress")
data["orderShippingAddress"] = extract_city_name("orderShippingAddress")

data.head(3)
# Out:
#     customerPhone        customerDevice customerBillingAddress orderId  \
# 0    400-108-5415  yyeiaxpltf82440jnb3v                     CA  vjbdvd
# 1  1-788-091-7546  r0jpm7xaeqqa3kr6mzum                     NM  yp6x27
# 2    024.420.0375  4m7h5ipl1shyavt6vv2r                     PR  nlghpa
#
#    orderAmount orderState orderShippingAddress paymentMethodId  \
# 0         18.0    pending                   CA       wt07xm68b
# 1         26.0  fulfilled                   CA       y3xp697jx
# 2         45.0  fulfilled                   CA       6krszxc05
#
#   paymentMethodRegistrationFailure paymentMethodType paymentMethodProvider  \
# 0                             True              card          JCB 16 digit
# 1                             True           bitcoin         VISA 16 digit
# 2                            False              card         VISA 16 digit
#
#     paymentMethodIssuer transactionId  transactionAmount  transactionFailed  \
# 0  Citizens First Banks      a9lcj51r                 18              False
# 1          Solace Banks      y4wcv03i                 26              False
# 2        Vertex Bancorp      5mi94sfw                 45              False
#
#   fraudulent emailDomain emailProvider customerIPAddressSimplified
# 0      False         com         yahoo                only_numbers
# 1       True         com         yahoo                only_numbers
# 2      False         com         yahoo          digits_and_letters

# %%
# También podemos evaluar que la ciudad de `customerBillingAddress` y `orderShippingAddress` coinciden.
# Aclaración: Esto se puede hacer usando funciones lambda o np.where, pero es más práctico de seguir / entender lo que hace el programa de la siguiente manera:

# Vamos a considerar si una de las 2 address al momento de comparar es `unknown`, le asignaremos como resultado `unknown`. Si ambas coinciden asignaremos `yes` y caso contrario `no`.

same_city = []

for index in range(len(data)):
    billing_address = data["customerBillingAddress"][index]
    order_address = data["orderShippingAddress"][index]

    response = "unknown"
    if billing_address != "unknown" and order_address != "unknown":
        if billing_address == order_address:
            response = "yes"
        else:
            response = "no"
    
    same_city.append(response)

data["sameCity"] = same_city

data.head(3)
# Out:
#     customerPhone        customerDevice customerBillingAddress orderId  \
# 0    400-108-5415  yyeiaxpltf82440jnb3v                     CA  vjbdvd
# 1  1-788-091-7546  r0jpm7xaeqqa3kr6mzum                     NM  yp6x27
# 2    024.420.0375  4m7h5ipl1shyavt6vv2r                     PR  nlghpa
#
#    orderAmount orderState orderShippingAddress paymentMethodId  \
# 0         18.0    pending                   CA       wt07xm68b
# 1         26.0  fulfilled                   CA       y3xp697jx
# 2         45.0  fulfilled                   CA       6krszxc05
#
#   paymentMethodRegistrationFailure paymentMethodType paymentMethodProvider  \
# 0                             True              card          JCB 16 digit
# 1                             True           bitcoin         VISA 16 digit
# 2                            False              card         VISA 16 digit
#
#     paymentMethodIssuer transactionId  transactionAmount  transactionFailed  \
# 0  Citizens First Banks      a9lcj51r                 18              False
# 1          Solace Banks      y4wcv03i                 26              False
# 2        Vertex Bancorp      5mi94sfw                 45              False
#
#   fraudulent emailDomain emailProvider customerIPAddressSimplified sameCity
# 0      False         com         yahoo                only_numbers      yes
# 1       True         com         yahoo                only_numbers       no
# 2      False         com         yahoo          digits_and_letters       no

# %%
# Con las columnas `customerBillingAddress` y `orderShippingAddress` se podría hacer un diagrama de flujo o de conexiones geoespacial o representarlo en un mapa.
# Conforme nuestra cartera de clientes crezca y tengamos más ciudades, más posibles valores tomarán las columnas `customerBillingAddress` y `orderShippingAddress`. En cambio `sameCity` va a seguir teniendo los mismos 3 posibles valores.
# Bajo ese criterio  vamos a despreciar ambas columnas y solo conservaremos `sameCity`.

data = data.drop(["customerBillingAddress", "orderShippingAddress"], axis = 1)

data.head(3)
# Out:
#     customerPhone        customerDevice orderId  orderAmount orderState  \
# 0    400-108-5415  yyeiaxpltf82440jnb3v  vjbdvd         18.0    pending
# 1  1-788-091-7546  r0jpm7xaeqqa3kr6mzum  yp6x27         26.0  fulfilled
# 2    024.420.0375  4m7h5ipl1shyavt6vv2r  nlghpa         45.0  fulfilled
#
#   paymentMethodId paymentMethodRegistrationFailure paymentMethodType  \
# 0       wt07xm68b                             True              card
# 1       y3xp697jx                             True           bitcoin
# 2       6krszxc05                            False              card
#
#   paymentMethodProvider   paymentMethodIssuer transactionId  \
# 0          JCB 16 digit  Citizens First Banks      a9lcj51r
# 1         VISA 16 digit          Solace Banks      y4wcv03i
# 2         VISA 16 digit        Vertex Bancorp      5mi94sfw
#
#    transactionAmount  transactionFailed fraudulent emailDomain emailProvider  \
# 0                 18              False      False         com         yahoo
# 1                 26              False       True         com         yahoo
# 2                 45              False      False         com         yahoo
#
#   customerIPAddressSimplified sameCity
# 0                only_numbers      yes
# 1                only_numbers       no
# 2          digits_and_letters       no

# %%
# customerPhone

# El número de teléfono prácticamente es un identificador único.
# Pero lo que se podría hacer es obtener el código de área para saber dónde está registrado el celular. 
# Por ejemplo: Un número "+54 9 261-1234-578", se podría extraer el primer número y buscar de qué país es. En este caso el +54 corresponde a Argentina y el 261 a la provincia de Mendoza.

# Y de esa manera se podría corroborar que el número del usuario tiene una correspondencia con el país o ciudad donde reside la persona.

# En este caso hay un universo de posibilidades en cómo se presenta el dato en `customerPhone` y no registra un patrón. Si tuvieramos más contexto podríamos conservar la columna.
# Por este motivo vamos a eliminar la columna:

data = data.drop(['customerPhone'], axis=1)

data.head(3)
# Out:
#          customerDevice orderId  orderAmount orderState paymentMethodId  \
# 0  yyeiaxpltf82440jnb3v  vjbdvd         18.0    pending       wt07xm68b
# 1  r0jpm7xaeqqa3kr6mzum  yp6x27         26.0  fulfilled       y3xp697jx
# 2  4m7h5ipl1shyavt6vv2r  nlghpa         45.0  fulfilled       6krszxc05
#
#   paymentMethodRegistrationFailure paymentMethodType paymentMethodProvider  \
# 0                             True              card          JCB 16 digit
# 1                             True           bitcoin         VISA 16 digit
# 2                            False              card         VISA 16 digit
#
#     paymentMethodIssuer transactionId  transactionAmount  transactionFailed  \
# 0  Citizens First Banks      a9lcj51r                 18              False
# 1          Solace Banks      y4wcv03i                 26              False
# 2        Vertex Bancorp      5mi94sfw                 45              False
#
#   fraudulent emailDomain emailProvider customerIPAddressSimplified sameCity
# 0      False         com         yahoo                only_numbers      yes
# 1       True         com         yahoo                only_numbers       no
# 2      False         com         yahoo          digits_and_letters       no

# %%
# Identificadores únicos

# Muchas veces en este tipo de productos de prevención de fraude se busca reducir la fricción. Por eso tenemos distintos identificadores del dispositivo del usuario, tracking del producto, etc.
# En este caso tenemos identificadores únicos en las columnas `customerDevice`, `orderId`, `transactionId` y `paymentMethodId`. Por esa razón los vamos a eliminar.

data = data.drop(['customerDevice', 'orderId', 'transactionId', 'paymentMethodId'], axis=1)

data.head(3)
# Out:
#    orderAmount orderState paymentMethodRegistrationFailure paymentMethodType  \
# 0         18.0    pending                             True              card
# 1         26.0  fulfilled                             True           bitcoin
# 2         45.0  fulfilled                            False              card
#
#   paymentMethodProvider   paymentMethodIssuer  transactionAmount  \
# 0          JCB 16 digit  Citizens First Banks                 18
# 1         VISA 16 digit          Solace Banks                 26
# 2         VISA 16 digit        Vertex Bancorp                 45
#
#    transactionFailed fraudulent emailDomain emailProvider  \
# 0              False      False         com         yahoo
# 1              False       True         com         yahoo
# 2              False      False         com         yahoo
#
#   customerIPAddressSimplified sameCity
# 0                only_numbers      yes
# 1                only_numbers       no
# 2          digits_and_letters       no

# %%
status(data)
# Out:
#                             variable  q_nan     p_nan  q_zeros   p_zeros  \
# 0                        orderAmount    145  0.232745        0  0.000000
# 1                         orderState    145  0.232745        0  0.000000
# 2   paymentMethodRegistrationFailure    281  0.451043      302  0.484751
# 3                  paymentMethodType    281  0.451043        0  0.000000
# 4              paymentMethodProvider    281  0.451043        0  0.000000
# 5                paymentMethodIssuer    281  0.451043        0  0.000000
# 6                  transactionAmount      0  0.000000        0  0.000000
# 7                  transactionFailed      0  0.000000      455  0.730337
# 8                         fraudulent    455  0.730337      107  0.171750
# 9                        emailDomain      0  0.000000        0  0.000000
# 10                     emailProvider      0  0.000000        0  0.000000
# 11       customerIPAddressSimplified      0  0.000000        0  0.000000
# 12                          sameCity      0  0.000000        0  0.000000
#
#     unique     type
# 0       67  float64
# 1        3   object
# 2        2   object
# 3        4   object
# 4       10   object
# 5       20   object
# 6       67    int64
# 7        2     bool
# 8        2   object
# 9        6   object
# 10       5   object
# 11       2   object
# 12       3   object

# %%
# Guardar dataset como csv

# Guardamos el dataset adaptado con extensión .csv

filename = "data/customer_dataset.csv"
data.to_csv(filename, index = False)
